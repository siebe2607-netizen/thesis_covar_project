# %% [markdown]
# # Core Sandbox Boilerplate
# This notebook securely imports your `covar_engine` and dataset. Any analysis
# you do below will not modify the primary `.py` codebase!

# %%
import sys
import os
import pandas as pd

# Mount the primary engine repository
root_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if root_dir not in sys.path:
    sys.path.append(root_dir)

from covar_engine import run_full_pipeline, run_sensitivity_analysis

# Load dataset
CSV_PATH = os.path.expanduser('~/Downloads/thesis_full_df_backup_final.csv')
df = pd.read_csv(CSV_PATH, index_col=0, parse_dates=True)
print(f"Successfully loaded pristine dataset of shape {df.shape}")
